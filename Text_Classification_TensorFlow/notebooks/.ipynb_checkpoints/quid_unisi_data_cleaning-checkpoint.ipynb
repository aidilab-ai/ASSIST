# %%
from nltk.tokenize import word_tokenize
import xml.etree.ElementTree as etree
from nltk.corpus import stopwords
from collections import Counter
import pandas as pd
import numpy as np
import sys
import re

# %%
sys.path.insert(0, '..')
from email_body_cleaner import clean_email_body

# %%
# Access the root of the XML document
root = etree.parse('../data/quid_unisi/HelpDeskRizzo.xml').getroot()

# %%
relevant_column_names = [
    'id', 
    'subject', 
    'content', 
    'intervento'
]    

relevant_column_indices = [
    0, # id
    1, # subject
    2, # content
    5  # intervento
]

# This will hold dataframe values
dataframe_values = []

# Extract relevant information from the XML file
for row in root.findall('records/row'):
    
    node_attrs = row.findall('column')
    node_attrs = list( map(lambda col: col.text, node_attrs) )
    node_attrs = np.array(node_attrs)[relevant_column_indices]
    
    dataframe_values.append(node_attrs)
    
# Create the dataframe    
dataframe_values = np.reshape(dataframe_values, (-1, len(relevant_column_indices)))
dataframe = pd.DataFrame(dataframe_values, columns=relevant_column_names)

# %%
dataframe
# Out:
#         id                                            subject  \
# 0     2039                                  segnalazione Ugov
# 1     3566  Re: VoIP@Unisi - Attenzione: la linea telefoni...
# 2     3566  Re: VoIP@Unisi - Attenzione: la linea telefoni...
# 3     4144                               oracle per CaricaCsa
# 4     4570                                 problema con email
# 5     4570                                 problema con email
# 6     5738                           richiesta di 3 terminali
# 7     6056                            ... programma Time&Work
# 8     7037    sostituzione apparato mobile convenzione consip
# 9     7037    sostituzione apparato mobile convenzione consip
# 10    7114  verifica funzionamento stampanti da remoto : V...
# 11    7140                      Installazione Dike versione 6
# 12    7823                volontari Servizio Civile Nazionale
# 13    7823                volontari Servizio Civile Nazionale
# 14    7981  Fw: richiesta apertura indirizzo per invio not...
# 15    7981  Fw: richiesta apertura indirizzo per invio not...
# 16    8010                             installazione Synology
# 17    8239                                              Help!
# 18    8239                                              Help!
# 19    8367                                      Problemi wifi
# 20    8518  Principali malfunzionamenti telefonia segreter...
# 21    8592              richiesta intervento direzione DFCLAM
# 22    8592              richiesta intervento direzione DFCLAM
# 23    8676    collegamento LAN stanza 458 palazzo san Niccolò
# 24    8685                                  Problemi con exel
# 25    8708       malfunzionamento rete studio 441 San Niccolò
# 26    8730                           Richiesta disattivazione
# 27    8730                           Richiesta disattivazione
# 28    8756  Fwd: Richiesta appuntamento per configurazione...
# 29    8756  Fwd: Richiesta appuntamento per configurazione...
# ..     ...                                                ...
# 616  10978               Comunicazione indirizzo mail privato
# 617  10997               Comunicazione indirizzo mail privato
# 618  11005               Information about application Status
# 619  11006               Comunicazione indirizzo mail privato
# 620  11012  BALDI LUCIA: richiesta credenziali accesso Sta...
# 621  11012  BALDI LUCIA: richiesta credenziali accesso Sta...
# 622  11014                   Fwd: Timbratrici non funzionanti
# 623  11014                   Fwd: Timbratrici non funzionanti
# 624  11015                                    Re: Accesso VPN
# 625  11015                                    Re: Accesso VPN
# 626  11017               Comunicazione indirizzo mail privato
# 627  11018               difficoltà login segreteria on line
# 628  11018               difficoltà login segreteria on line
# 629  11019               Comunicazione indirizzo mail privato
# 630  11020  Fwd: C’è più futuro di quanto si possa immagin...
# 631  11020  Fwd: C’è più futuro di quanto si possa immagin...
# 632  11022             Re: UNISIPASS: Reimpostazione password
# 633  11022             Re: UNISIPASS: Reimpostazione password
# 634  11029  BALDI ROBERTA : richiesta credenziali accesso ...
# 635  11029  BALDI ROBERTA : richiesta credenziali accesso ...
# 636  11033               Comunicazione indirizzo mail privato
# 637  11035                               Richiesta assistenza
# 638  11037                             problema su "Presenze"
# 639  11037                             problema su "Presenze"
# 640  11048  Re: VoIP@Unisi - Promemoria restituzione termi...
# 641  11055  Fwd: Il tuo messaggio a Info-stud attende l'ap...
# 642  11055  Fwd: Il tuo messaggio a Info-stud attende l'ap...
# 643  11065  mancato funzionamento codice 5 a timbratore de...
# 644  11067  Re: VoIP@Unisi - Notifica di disattivazione Do...
# 645  11067  Re: VoIP@Unisi - Notifica di disattivazione Do...
#
#                                                content  \
# 0    Buongiorno\n\ninvio in allegato messaggio che ...
# 1    Gentile Pinassi,\n\ncome gi=C3=A0 comunicato i...
# 2    <html>\n  <head>\n    <meta http-equiv=3D"Cont...
# 3    Gentili colleghi,\n\nper poter caricare i file...
# 4    Carissimi,\n\nieri sera hanno cominciato ad ar...
# 5    <html><head><meta http-equiv=3D"Content-Type" ...
# 6    Cari colleghi, come gi=C3=A0 accennato a voce,...
# 7    Gentili colleghe/i,\n\nla presente =C3=A8 per ...
# 8    <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2//E...
# 9    Egregio Dott. Pinassi,\nmi si =C3=A8 rotto il ...
# 10   Gentilissime/i,\n\ncon la presente vi chiedere...
# 11   Buongiorno,\n\ncome da accordi verbali con Cio...
# 12   Gentili colleghi,\n\nchiedo con la presente l=...
# 13   <HTML><HEAD></HEAD>\n<BODY dir=3Dltr>\n<DIV di...
# 14   Buongiorno,\nIn merito ai problemi che stiamo ...
# 15   <div id=3D"__MailbirdStyleContent" style=3D"fo...
# 16   Buongiorno,\n\nrichiedo gentilmente di istalla...
# 17   Con la presente si richiede l'assistenza tecni...
# 18   <html>\n  <head>\n\n    <meta http-equiv=3D"co...
# 19   Salve, sono uno studente unisi e scrivo dalla ...
# 20   \n\nCaro Michele,\n\ncome da accordi con Enric...
# 21   <div dir=3D"ltr"><div class=3D"gmail_default" ...
# 22   Gentili Colleghi,\nchiedo il vostri intervento...
# 23   Vi scrivo in relazione all'assenza di collegam...
# 24   Buongiorno gentili colleghi, segnaliamo alcune...
# 25   Gentili Colleghi,\n\nvi segnalo che la conness...
# 26   Gent.mi,\n\nvi chiedo di disattivare la mail o...
# 27   <html><head><meta http-equiv=3D"Content-Type" ...
# 28   Buongiorno,\n\ncon la presente desidero rinnov...
# 29   <div dir=3D"ltr"><div dir=3D"ltr">Buongiorno,<...
# ..                                                 ...
# 616  Comunicazione indirizzo mail privato\n=20=20=2...
# 617  Comunicazione indirizzo mail privato\n=20=20=2...
# 618  <div dir=3D"ltr"><br clear=3D"all"><div>Dear S...
# 619  Comunicazione indirizzo mail privato\n=20=20=2...
# 620  Gentile Dottoressa,\nci viene segnalato che no...
# 621  <html>\n  <head>\n\n    <meta http-equiv=3D"co...
# 622  Buongiorno,\ninoltro la mail pervenuta in data...
# 623  <html>\n  <head>\n\n    <meta http-equiv=3D"co...
# 624  Caro Nicola,\ninoltro la tua chiamata al centr...
# 625  <html>\n  <head>\n    <meta http-equiv=3D"Cont...
# 626  Comunicazione indirizzo mail privato\n=20=20=2...
# 627   Buongiorno,sono Paola Belliconi iscritta al c...
# 628  &nbsp;Buongiorno,<div>sono Paola Belliconi isc...
# 629  Comunicazione indirizzo mail privato\n=20=20=2...
# 630  Car* colleg*,\ncome potrei fare a non ricevere...
# 631  <html>\n  <head>\n\n    <meta http-equiv=3D"co...
# 632  <div dir=3D"ltr">Ho cliccato sul link:<div><a ...
# 633  Ho cliccato sul link:\nhttps://my.unisi.it/con...
# 634  Buonasera,\ncon la presente si chiede di forni...
# 635  <html>\n  <head>\n\n    <meta http-equiv=3D"co...
# 636  Comunicazione indirizzo mail privato\n=20=20=2...
# 637  Gent.mi,\n\nSono dottorando di ricerca del XXX...
# 638  Ci dobbiamo preoccupare? questo il messaggio c...
# 639  <html>\n  <head>\n\n    <meta http-equiv=3D"co...
# 640  Buongiorno,\n\noggi scade il mio assegno di ri...
# 641  Come da accordi con Francesco chiedo di poter ...
# 642  <div dir=3D"ltr"><div class=3D"gmail_quote">Co...
# 643  Ci segnalano che non funziona il codice 5=C2=A...
# 644  <html>\n  <head>\n    <meta http-equiv=3D"Cont...
# 645  Salve\n\nvolevo comunica che il mio telefono n...
#
#                                             intervento
# 0                   Informazioni e supporto funzionale
# 1                   Informazioni e supporto funzionale
# 2                   Informazioni e supporto funzionale
# 3                    Malfunzionamento SW specialistico
# 4                   Informazioni e supporto funzionale
# 5                   Informazioni e supporto funzionale
# 6                                                 None
# 7                   Informazioni e supporto funzionale
# 8                                Sostituzione apparato
# 9                                Sostituzione apparato
# 10                  Informazioni e supporto funzionale
# 11                                                None
# 12   Installazione/Aggiornamento/Disinstallazione S...
# 13   Installazione/Aggiornamento/Disinstallazione S...
# 14          Creazione/Modifica/Rimozione di uno spazio
# 15          Creazione/Modifica/Rimozione di uno spazio
# 16   Installazione/Aggiornamento/Disinstallazione S...
# 17            Malfunzionamento HW Postazione di Lavoro
# 18            Malfunzionamento HW Postazione di Lavoro
# 19                                                None
# 20                           Malfunzionamento fonia IP
# 21                                                None
# 22                                                None
# 23                                                None
# 24                   Creazione di un nuovo PC virtuale
# 25                                                None
# 26   Creazione/Modifica/Revoca di una casella condi...
# 27   Creazione/Modifica/Revoca di una casella condi...
# 28                          Nuova Postazione di Lavoro
# 29                          Nuova Postazione di Lavoro
# ..                                                 ...
# 616               Supporto recupero password unisiPass
# 617               Supporto recupero password unisiPass
# 618                                               None
# 619               Supporto recupero password unisiPass
# 620                                               None
# 621                                               None
# 622           Malfunzionamento HW Postazione di Lavoro
# 623           Malfunzionamento HW Postazione di Lavoro
# 624                   Creazione/Modifica/Revoca utenza
# 625                   Creazione/Modifica/Revoca utenza
# 626               Supporto recupero password unisiPass
# 627               Supporto recupero password unisiPass
# 628               Supporto recupero password unisiPass
# 629               Supporto recupero password unisiPass
# 630                 Informazioni e supporto funzionale
# 631                 Informazioni e supporto funzionale
# 632                 Informazioni e supporto funzionale
# 633                 Informazioni e supporto funzionale
# 634                 Informazioni e supporto funzionale
# 635                 Informazioni e supporto funzionale
# 636         Malfunzionamento sistema recupero password
# 637                   Creazione/Modifica/Revoca utenza
# 638                         Gestione utenze temporanee
# 639                         Gestione utenze temporanee
# 640                 Informazioni e supporto funzionale
# 641                 Informazioni e supporto funzionale
# 642                 Informazioni e supporto funzionale
# 643           Malfunzionamento HW Postazione di Lavoro
# 644                                 Richieste fonia IP
# 645                                 Richieste fonia IP
#
# [646 rows x 4 columns]

# %% [markdown]
# As we can see, there are some duplicate rows (they have the same 'id'). The body of the email (column 'content') is the same for both, however in one case the body is wrapped in HTML tags. What we want to do is to remove such rows

# %%
# Add dummy column representing the number of characters of attribute 'content'
dataframe['content_length'] = list(map(len, dataframe['content'].values))

# Since it is evident that the row in which the email body is wrapped in HTML tags will have a larger value
# of 'content_length' compared to the one where the body is not wrapped in HTML tags, we do the following:
#  1) Sort rows by content_length in ascending order
#  2) Drop duplicate rows, keeping the first occurrence (namely the one whose content_length is minimum)
dataframe = dataframe.sort_values('content_length')
dataframe = dataframe.drop_duplicates('id', keep='first')

# Drop the dummy column introduced earlier on
dataframe = dataframe.drop(columns=['content_length'])

# Restore the original ordering of the dataframe's rows
dataframe = dataframe.sort_index()

# %%
# Clean up emails bodies, as there are a lot of weird characters and newlines
dataframe['content'] = dataframe['content'].apply(clean_email_body)

# %%
# Indices of examples containing english text, html tags and other things
bad_rows_indices = [83, 93, 98, 99, 128, 129, 168, 250, 274, 
                    295, 330, 367, 369, 375, 376, 381, 463, 
                    490, 499, 557, 578, 597, 599, 600, 604, 
                    618]

dataframe = dataframe.drop(index=bad_rows_indices)

# %%
special_characters_regex_pattern = '[\W_]+'
single_letter_regex_pattern = '[a-zA-Z]'
numbers_regex_pattern = '[0-9]+'
hours_regex_pattern = '\d+[\.:]\d+([\.:]\d+)?'
dates_regex_pattern = '\d+[-/]\d+([-/]\d+)?'

regex = re.compile('^({spec}|{lett}|{num}|{hour}|{date})$'.format(spec=special_characters_regex_pattern, 
                                                                  lett=single_letter_regex_pattern, 
                                                                  num=numbers_regex_pattern,
                                                                  hour=hours_regex_pattern,
                                                                  date=dates_regex_pattern))

words = []
for email_body in dataframe['content'].values:

    tokens = word_tokenize(email_body, language='italian')
    
    # Remove tokens that match the regular expression
    tokens = [tok for tok in tokens if not regex.search(tok)]

    # Remove stopwords
    tokens = [tok for tok in tokens if not tok in stopwords.words('italian')]
    
    words.extend(tokens)

words = list( map(str.lower, words) )    
vocabulary = list( set(words) )

# %%
Counter(vocabulary)['cari']
# Out:
# 2

# %%
# Class labels
dataframe['intervento'].value_counts()
# Out:
# Supporto recupero password unisiPass                             169
# Informazioni e supporto funzionale                               131
# Creazione/Modifica/Revoca di una casella di posta personale       12
# Richieste fonia IP                                                10
# Malfunzionamento fonia IP                                         10
# Malfunzionamento HW Postazione di Lavoro                          10
# Aggiornamento/Assistenza/Manutenzione rubrica telefonica           8
# Installazione/Aggiornamento/Disinstallazione SW standard           7
# Creazione/Modifica/Revoca di una casella condivisa e alias         6
# Problematiche funzionali                                           5
# Creazione/Modifica/Rimozione di uno spazio                         5
# Malfunzionamento casella                                           4
# Creazione/Modifica/Revoca utenza                                   4
# Malfunzionamento SW specialistico                                  4
# Malfunzionamento SW standard                                       4
# Trasloco                                                           3
# Malfunzionamento VPN                                               3
# Malfunzionamento sistema recupero password                         3
# Installazione/Aggiornamento/Disinstallazione SW specialistico      3
# Nuova Postazione di Lavoro                                         3
# Installazione/disinstallazione periferiche non di rete             3
# Malfunzionamento server virtuale                                   2
# Creazione di un nuovo PC virtuale                                  2
# Malfunzionamento                                                   2
# Malfunzionamento Wi-Fi                                             2
# Malfunzionamento fonia analogica                                   2
# Creazione/Modifica/Cancellazione                                   1
# Malfunzionamento terminale                                         1
# Sostituzione HW Postazione di Lavoro                               1
# Gestione utenze temporanee                                         1
# Sostituzione apparato                                              1
# Configurazione porte di rete                                       1
# Name: intervento, dtype: int64
